# %% [markdown]
# <a href="https://colab.research.google.com/github/V6388/Data_visualization-on-iris.csv-data-set/blob/main/text_iris_csv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
iris=pd.read_csv('iris.csv')

# %%
iris.head(100)
# Out:
#     Sepal.Length  Sepal.Width  Petal.Length  Petal.Width     Species
# 0            5.1          3.5           1.4          0.2      setosa
# 1            4.9          3.0           1.4          0.2      setosa
# 2            4.7          3.2           1.3          0.2      setosa
# 3            4.6          3.1           1.5          0.2      setosa
# 4            5.0          3.6           1.4          0.2      setosa
# ..           ...          ...           ...          ...         ...
# 95           5.7          3.0           4.2          1.2  versicolor
# 96           5.7          2.9           4.2          1.3  versicolor
# 97           6.2          2.9           4.3          1.3  versicolor
# 98           5.1          2.5           3.0          1.1  versicolor
# 99           5.7          2.8           4.1          1.3  versicolor
#
# [100 rows x 5 columns]

# %%
iris.tail()
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
iris.describe()
# Out:
#        Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris.iloc[0:13,0:3]
# Out:
#     Sepal.Length  Sepal.Width  Petal.Length
# 0            5.1          3.5           1.4
# 1            4.9          3.0           1.4
# 2            4.7          3.2           1.3
# 3            4.6          3.1           1.5
# 4            5.0          3.6           1.4
# 5            5.4          3.9           1.7
# 6            4.6          3.4           1.4
# 7            5.0          3.4           1.5
# 8            4.4          2.9           1.4
# 9            4.9          3.1           1.5
# 10           5.4          3.7           1.5
# 11           4.8          3.4           1.6
# 12           4.8          3.0           1.4

# %%
iris.iloc[45:65,[0,4]]
# Out:
#     Sepal.Length     Species
# 45           4.8      setosa
# 46           5.1      setosa
# 47           4.6      setosa
# 48           5.3      setosa
# 49           5.0      setosa
# 50           7.0  versicolor
# 51           6.4  versicolor
# 52           6.9  versicolor
# 53           5.5  versicolor
# 54           6.5  versicolor
# 55           5.7  versicolor
# 56           6.3  versicolor
# 57           4.9  versicolor
# 58           6.6  versicolor
# 59           5.2  versicolor
# 60           5.0  versicolor
# 61           5.9  versicolor
# 62           6.0  versicolor
# 63           6.1  versicolor
# 64           5.6  versicolor

# %%
ir=iris.loc[10:20,("Sepal.Length","Petal.Length")]

# %%
ir
# Out:
#     Sepal.Length  Petal.Length
# 10           5.4           1.5
# 11           4.8           1.6
# 12           4.8           1.4
# 13           4.3           1.1
# 14           5.8           1.2
# 15           5.7           1.5
# 16           5.4           1.3
# 17           5.1           1.4
# 18           5.7           1.7
# 19           5.1           1.5
# 20           5.4           1.7

# %%
iris.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris['Sepal.Length']>5
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 145     True
# 146     True
# 147     True
# 148     True
# 149     True
# Name: Sepal.Length, Length: 150, dtype: bool

# %%
iris[iris['Sepal.Length']>5]
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 0             5.1          3.5           1.4          0.2     setosa
# 5             5.4          3.9           1.7          0.4     setosa
# 10            5.4          3.7           1.5          0.2     setosa
# 14            5.8          4.0           1.2          0.2     setosa
# 15            5.7          4.4           1.5          0.4     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [118 rows x 5 columns]

# %%
iris1=iris[(iris['Sepal.Length']>5) & (iris['Species']=='virginica')]

# %%
iris1
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 100           6.3          3.3           6.0          2.5  virginica
# 101           5.8          2.7           5.1          1.9  virginica
# 102           7.1          3.0           5.9          2.1  virginica
# 103           6.3          2.9           5.6          1.8  virginica
# 104           6.5          3.0           5.8          2.2  virginica
# 105           7.6          3.0           6.6          2.1  virginica
# 107           7.3          2.9           6.3          1.8  virginica
# 108           6.7          2.5           5.8          1.8  virginica
# 109           7.2          3.6           6.1          2.5  virginica
# 110           6.5          3.2           5.1          2.0  virginica
# 111           6.4          2.7           5.3          1.9  virginica
# 112           6.8          3.0           5.5          2.1  virginica
# 113           5.7          2.5           5.0          2.0  virginica
# ...

# %%
iris2=iris[(iris['Sepal.Length']>5) & (iris['Species']=='virginica') & (iris['Petal.Length']>6)]

# %%
iris2
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 105           7.6          3.0           6.6          2.1  virginica
# 107           7.3          2.9           6.3          1.8  virginica
# 109           7.2          3.6           6.1          2.5  virginica
# 117           7.7          3.8           6.7          2.2  virginica
# 118           7.7          2.6           6.9          2.3  virginica
# 122           7.7          2.8           6.7          2.0  virginica
# 130           7.4          2.8           6.1          1.9  virginica
# 131           7.9          3.8           6.4          2.0  virginica
# 135           7.7          3.0           6.1          2.3  virginica
